# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
fifa=pd.read_csv('data.csv')

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
for col in fifa.columns:
    print(col)
# Out:
# Unnamed: 0
# ID
# Name
# Age
# Photo
# Nationality
# Flag
# Overall
# Potential
# Club
# Club Logo
# Value
# Wage
# Special
# Preferred Foot
# International Reputation
# Weak Foot
# Skill Moves
# Work Rate
# Body Type
# Real Face
# Position
# Jersey Number
# Joined
# Loaned From
# Contract Valid Until
# Height
# Weight
# LS
# ST
# RS
# LW
# LF
# CF
# RF
# RW
# LAM
# CAM
# RAM
# LM
# LCM
# CM
# RCM
# RM
# LWB
# LDM
# CDM
# RDM
# RWB
# LB
# LCB
# CB
# RCB
# RB
# Crossing
# Finishing
# HeadingAccuracy
# ShortPassing
# Volleys
# Dribbling
# Curve
# FKAccuracy
# LongPassing
# BallControl
# Acceleration
# SprintSpeed
# Agility
# Reactions
# Balance
# ShotPower
# Jumping
# Stamina
# Strength
# LongShots
# Aggression
# Interceptions
# Positioning
# Vision
# Penalties
# Composure
# Marking
# StandingTackle
# SlidingTackle
# GKDiving
# GKHandling
# GKKicking
# GKPositioning
# GKReflexes
# Release Clause

# %%
fifa.shape
# Out:
# (18207, 89)

# %%
fifa['Nationality'].value_counts()
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
#                ...
# St Lucia          1
# Guam              1
# Rwanda            1
# Puerto Rico       1
# Belize            1
# Name: Nationality, Length: 164, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:10]
# Out:
# England        1662
# Germany        1198
# Spain          1072
# Argentina       937
# France          914
# Brazil          827
# Italy           702
# Colombia        618
# Japan           478
# Netherlands     453
# Name: Nationality, dtype: int64

# %%
fifa['Nationality'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'Argentina', 'France', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %%
plt.figure(figsize=(5,5))
plt.bar(list(fifa['Nationality'].value_counts()[0:5].keys()),fifa['Nationality'].value_counts()[0:5],color='g')
# Out:
# <BarContainer object of 5 artists>

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
player_salary=fifa[['Name','Wage']]
player_salary.head()
# Out:
#                 Name   Wage
# 0           L. Messi  €565K
# 1  Cristiano Ronaldo  €405K
# 2          Neymar Jr  €290K
# 3             De Gea  €260K
# 4       K. De Bruyne  €355K

# %%
player_salary=player_salary.sort_values(by=['Wage'],ascending=False)
player_salary.head()
# Out:
#               Name Wage
# 6615   C. Teuchert  €9K
# 2136     M. Luongo  €9K
# 1556      A. Gomis  €9K
# 8843  A. Al Ghamdi  €9K
# 6301   T. Weilandt  €9K

# %%
plt.figure(figsize=(8,5))
plt.bar(list(player_salary['Name'])[0:5],player_salary['Wage'].value_counts()[0:5],color='pink')
# Out:
# <BarContainer object of 5 artists>

# %%
fifa['Nationality']=='Argentina'
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 18202    False
# 18203    False
# 18204    False
# 18205    False
# 18206    False
# Name: Nationality, Length: 18207, dtype: bool

# %%
Arg=fifa['Nationality']=='Argentina'
Arg.head(10)
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: Nationality, dtype: bool

# %%
Arg=Arg=fifa[fifa['Nationality']=='Argentina']
Arg.head()
# Out:
#     Unnamed: 0      ID        Name  Age  \
# 0            0  158023    L. Messi   31
# 15          15  211110   P. Dybala   24
# 23          23  153079   S. Agüero   30
# 38          38  167664  G. Higuaín   30
# 43          43  201399   M. Icardi   25
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 23  https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38  https://cdn.sofifa.org/players/4/19/167664.png   Argentina
# 43  https://cdn.sofifa.org/players/4/19/201399.png   Argentina
#
#                                    Flag  Overall  Potential             Club  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94     FC Barcelona
# 15  https://cdn.sofifa.org/flags/52.png       89         94         Juventus
# 23  https://cdn.sofifa.org/flags/52.png       89         89  Manchester City
# ...

# %%
Arg.sort_values(by=['Potential'],ascending=False).head()
# Out:
#     Unnamed: 0      ID        Name  Age  \
# 0            0  158023    L. Messi   31
# 15          15  211110   P. Dybala   24
# 43          43  201399   M. Icardi   25
# 23          23  153079   S. Agüero   30
# 38          38  167664  G. Higuaín   30
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 15  https://cdn.sofifa.org/players/4/19/211110.png   Argentina
# 43  https://cdn.sofifa.org/players/4/19/201399.png   Argentina
# 23  https://cdn.sofifa.org/players/4/19/153079.png   Argentina
# 38  https://cdn.sofifa.org/players/4/19/167664.png   Argentina
#
#                                    Flag  Overall  Potential             Club  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94     FC Barcelona
# 15  https://cdn.sofifa.org/flags/52.png       89         94         Juventus
# 43  https://cdn.sofifa.org/flags/52.png       87         90            Inter
# ...

# %%
Arg.sort_values(by=['Weight'],ascending=False).head()
# Out:
#       Unnamed: 0      ID        Name  Age  \
# 9443        9443  235925    G. Gómez   22
# 5952        5952  223064  F. Noguera   25
# 8392        8392  222889  L. Acevedo   26
# 2504        2504  227275    A. Rossi   22
# 920          920  176919   N. Guzmán   32
#
#                                                Photo Nationality  \
# 9443  https://cdn.sofifa.org/players/4/19/235925.png   Argentina
# 5952  https://cdn.sofifa.org/players/4/19/223064.png   Argentina
# 8392  https://cdn.sofifa.org/players/4/19/222889.png   Argentina
# 2504  https://cdn.sofifa.org/players/4/19/227275.png   Argentina
# 920   https://cdn.sofifa.org/players/4/19/176919.png   Argentina
#
#                                      Flag  Overall  Potential  \
# 9443  https://cdn.sofifa.org/flags/52.png       66         75
# 5952  https://cdn.sofifa.org/flags/52.png       69         74
# 8392  https://cdn.sofifa.org/flags/52.png       67         70
# 2504  https://cdn.sofifa.org/flags/52.png       74         82
# ...

# %%
Arg.sort_values(by=['Value'],ascending=False).head()
# Out:
#       Unnamed: 0      ID          Name  Age  \
# 981          981  226378      R. Ábila   28
# 1309        1309  211269  G. Fernández   26
# 1428        1428  236441     F. Bustos   22
# 526          526  173373     S. Romero   31
# 524          524  176376     I. Piatti   33
#
#                                                Photo Nationality  \
# 981   https://cdn.sofifa.org/players/4/19/226378.png   Argentina
# 1309  https://cdn.sofifa.org/players/4/19/211269.png   Argentina
# 1428  https://cdn.sofifa.org/players/4/19/236441.png   Argentina
# 526   https://cdn.sofifa.org/players/4/19/173373.png   Argentina
# 524   https://cdn.sofifa.org/players/4/19/176376.png   Argentina
#
#                                      Flag  Overall  Potential  \
# 981   https://cdn.sofifa.org/flags/52.png       77         77
# 1309  https://cdn.sofifa.org/flags/52.png       76         77
# 1428  https://cdn.sofifa.org/flags/52.png       76         83
# ...

# %%
Arg[['Name','Wage']].sort_values(by=['Wage'],ascending=False).head()
# Out:
#             Name Wage
# 3214  I. Damonte  €9K
# 4712   G. Acosta  €9K
# 6563    L. Grimi  €9K
# 6490  N. Reniero  €9K
# 3382   J. Galván  €9K

# %%
player_dribbling=fifa[['Name','Dribbling']]
player_dribbling.head()
# Out:
#                 Name  Dribbling
# 0           L. Messi       97.0
# 1  Cristiano Ronaldo       88.0
# 2          Neymar Jr       96.0
# 3             De Gea       18.0
# 4       K. De Bruyne       86.0

# %%
player_dribbling.sort_values(by=['Dribbling'],ascending=False).head()
# Out:
#           Name  Dribbling
# 0     L. Messi       97.0
# 2    Neymar Jr       96.0
# 5    E. Hazard       95.0
# 30        Isco       94.0
# 94  Y. Brahimi       93.0

# %%
player_agility=fifa[['Name','Agility','Nationality','Club']]

# %%
player_agility.sort_values(by=['Agility'],ascending=False).head()
# Out:
#              Name  Agility Nationality                 Club
# 2       Neymar Jr     96.0      Brazil  Paris Saint-Germain
# 6584  H. Nakagawa     95.0       Japan       Kashiwa Reysol
# 5       E. Hazard     95.0     Belgium              Chelsea
# 5086       T. Itō     95.0       Japan         Hamburger SV
# 3679    C. Galano     95.0       Italy               Foggia

# %%
barcelona=fifa[fifa['Club']=='FC Barcelona']
barcelona.head()
# Out:
#     Unnamed: 0      ID             Name  Age  \
# 0            0  158023         L. Messi   31
# 7            7  176580        L. Suárez   31
# 18          18  192448    M. ter Stegen   26
# 20          20  189511  Sergio Busquets   29
# 32          32  189242         Coutinho   26
#
#                                              Photo Nationality  \
# 0   https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 7   https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
# 18  https://cdn.sofifa.org/players/4/19/192448.png     Germany
# 20  https://cdn.sofifa.org/players/4/19/189511.png       Spain
# 32  https://cdn.sofifa.org/players/4/19/189242.png      Brazil
#
#                                    Flag  Overall  Potential          Club  \
# 0   https://cdn.sofifa.org/flags/52.png       94         94  FC Barcelona
# 7   https://cdn.sofifa.org/flags/60.png       91         91  FC Barcelona
# 18  https://cdn.sofifa.org/flags/21.png       89         92  FC Barcelona
# ...

# %%
barcelona.sort_values(by=['Wage'],ascending=False).head()
# Out:
#        Unnamed: 0      ID          Name  Age  \
# 3118         3118  208088  Sergi Samper   23
# 3684         3684  233113         Aleñá   20
# 0               0  158023      L. Messi   31
# 14286       14286  246139    Iñaki Peña   19
# 7               7  176580     L. Suárez   31
#
#                                                 Photo Nationality  \
# 3118   https://cdn.sofifa.org/players/4/19/208088.png       Spain
# 3684   https://cdn.sofifa.org/players/4/19/233113.png       Spain
# 0      https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 14286  https://cdn.sofifa.org/players/4/19/246139.png       Spain
# 7      https://cdn.sofifa.org/players/4/19/176580.png     Uruguay
#
#                                       Flag  Overall  Potential          Club  \
# 3118   https://cdn.sofifa.org/flags/45.png       73         80  FC Barcelona
# 3684   https://cdn.sofifa.org/flags/45.png       72         85  FC Barcelona
# ...

# %%
barcelona['Nationality'].value_counts()
# Out:
# Spain          17
# Brazil          4
# France          3
# Argentina       1
# Netherlands     1
# Uruguay         1
# Belgium         1
# Croatia         1
# Chile           1
# Germany         1
# Senegal         1
# Portugal        1
# Name: Nationality, dtype: int64
